# %%
import geopandas as gpd
import osmnx as ox

# %matplotlib inline
ox.__version__
# Out:
# '1.1.1'

# %%
boundary_json = gpd.read_file('half-cambridge.json')

# %%
poly=boundary_json.loc[0,'geometry']

# %%
poly

# %%
G_hc = ox.graph_from_polygon(poly, network_type="drive")

# %%
fig, ax = ox.plot_graph(G_hc, node_size=0, edge_color="w", edge_linewidth=0.2)

# %%
G_hc_proj=ox.project_graph(G_hc)
ox.save_graph_shapefile(G_hc_proj, filepath="./data/halfcambridge_road.shp")
# Out:
# /Users/naroacorettisanchez/anaconda3/envs/py36/lib/python3.6/site-packages/osmnx/io.py:108: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_nodes.to_file(filepath_nodes, driver="ESRI Shapefile", index=True, encoding=encoding)

# %%
boundary_json.to_file('halfcambridge-boundary')

# %%
from shapely.geometry import Point  #Polygon
import pandas as pd

# %%
demand_raw = pd.read_csv("./input_data/user_trips_0.csv")
demand_raw
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               176  2019-10-07 00:00:01.5740  2019-10-07 00:02:57.8570
# 1               193  2019-10-07 00:00:43.0660  2019-10-07 00:03:56.4360
# 2               159  2019-10-07 00:01:29.1760  2019-10-07 00:04:08.3340
# 3               540  2019-10-07 00:01:30.6650  2019-10-07 00:10:31.6250
# 4               531  2019-10-07 00:01:30.8390  2019-10-07 00:10:22.4090
# ...             ...                       ...                       ...
# 62187          1074  2019-10-13 23:58:29.5130  2019-10-14 00:16:24.0190
# 62188           384  2019-10-13 23:58:30.8800  2019-10-14 00:04:55.5750
# 62189           502  2019-10-13 23:58:37.6720  2019-10-14 00:07:00.3150
# 62190           311  2019-10-13 23:59:29.5320  2019-10-14 00:04:41.2130
# 62191           835  2019-10-13 23:59:55.1170  2019-10-14 00:13:51.0050
#
#        start station id                                 start station name  \
# 0                   108  Harvard University / SEAS Cruft-Pierce Halls a...
# 1                    10                      B.U. Central - 725 Comm. Ave.
# 2                     9                    Commonwealth Ave at Agganis Way
# 3                     3  Colleges of the Fenway - Fenway at Avenue Loui...
# 4                     3  Colleges of the Fenway - Fenway at Avenue Loui...
# ...                 ...                                                ...
# 62187                 3  Colleges of the Fenway - Fenway at Avenue Loui...
# 62188               177                                    University Park
# 62189                52                          Newbury St at Hereford St
# 62190                 9                    Commonwealth Ave at Agganis Way
# 62191                 4                        Tremont St at E Berkeley St
#
#        start station latitude  start station longitude  end station id  \
# 0                   42.377945               -71.116865              79
# 1                   42.350406               -71.108279              19
# 2                   42.351692               -71.119035              41
# 3                   42.340115               -71.100619              12
# 4                   42.340115               -71.100619              12
# ...                       ...                      ...             ...
# 62187               42.340115               -71.100619              37
# 62188               42.362648               -71.100061             105
# 62189               42.348717               -71.085954             122
# 62190               42.351692               -71.119035              66
# 62191               42.345392               -71.069616             342
#
#                                         end station name  \
# 0                     Beacon St at Washington / Kirkland
# 1                                  Park Dr at Buswell St
# 2      Packard's Corner - Commonwealth Ave at Brighto...
# 3      Ruggles T Stop - Columbus Ave at Melnea Cass Blvd
# 4      Ruggles T Stop - Columbus Ave at Melnea Cass Blvd
# ...                                                  ...
# 62187                          New Balance - 20 Guest St
# 62188  Lower Cambridgeport at Magazine St / Riverside Rd
# 62189                    Burlington Ave at Brookline Ave
# 62190  Allston Green District - Griggs St at Commonwe...
# 62191                           Boylston St at Jersey St
#
#        end station latitude  ...  birth year  gender start_building  \
# 0                 42.378420  ...        1983       1          87796
# 1                 42.347241  ...        1999       2            183
# 2                 42.352261  ...        1999       1         180997
# 3                 42.336244  ...        1969       0            201
# 4                 42.336244  ...        1969       0         202657
# ...                     ...  ...         ...     ...            ...
# 62187             42.357329  ...        1989       1         259759
# 62188             42.357219  ...        1996       1         225354
# 62189             42.345733  ...        1985       1         257268
# 62190             42.349225  ...        1997       1         224577
# 62191             42.344651  ...        1987       2         251112
#
#        start_lon  start_lat  target_building  target_lon  target_lat  \
# 0     -71.113726  42.377668            17007  -71.105017   42.378432
# 1     -71.111674  42.350137             1384  -71.104996   42.347869
# 2     -71.121202  42.350776           175311  -71.122811   42.350820
# 3     -71.103059  42.338554           259390  -71.084691   42.336693
# 4     -71.099701  42.338420           248527  -71.086064   42.336684
# ...          ...        ...              ...         ...         ...
# 62187 -71.103671  42.340555            62890  -71.146244   42.355139
# 62188 -71.102718  42.363217            32375  -71.111086   42.356037
# 62189 -71.085335  42.346976           162379  -71.102816   42.346085
# 62190 -71.118932  42.350876           185148  -71.135520   42.350418
# 62191 -71.068436  42.344313            23940  -71.098384   42.344760
#
#        start_time  target_time
# 0             1.0        177.0
# 1            43.0        236.0
# 2            89.0        248.0
# 3            90.0        631.0
# 4            90.0        622.0
# ...           ...          ...
# 62187    604709.0     605784.0
# 62188    604710.0     605095.0
# 62189    604717.0     605220.0
# 62190    604769.0     605081.0
# 62191    604795.0     605631.0
#
# [62192 rows x 23 columns]

# %%
# DATE FILTER
start_date = "2019-10-08 00:00:00"
end_date = "2019-10-09 00:00:00"
demand_raw = demand_raw[demand_raw["starttime"].between(start_date, end_date)]

# ROUNDTRIP FILTER
demand_raw = demand_raw[demand_raw["start station id"] != demand_raw["end station id"]]

# %%
# add new column to df
demand_raw['withinC'] = ""

#Determine if it is inside or not
startwithinClist = []
for lon,lat in zip(demand_raw['start_lon'],demand_raw['start_lat']):
    pt = Point(lon, lat)
    startwithinC = pt.within(poly)
    #print( withinQ )
    startwithinClist.append(startwithinC)

# update values in the that column, values: True/False
demand_raw['withinC'] = startwithinClist

# %%
# select points with start within Cambridge, assign to `demand_start_within` dataframe
demand_start_within = demand_raw[demand_raw.withinC==True]
demand_start_within
# Out:
#        tripduration                 starttime                  stoptime  \
# 9               597  2019-10-07 00:02:58.3520  2019-10-07 00:12:55.7150
# 15              240  2019-10-07 00:07:25.9850  2019-10-07 00:11:26.2400
# 19             4217  2019-10-07 00:11:19.1750  2019-10-07 01:21:36.4020
# 20              799  2019-10-07 00:11:37.2620  2019-10-07 00:24:56.6760
# 21              785  2019-10-07 00:11:47.9830  2019-10-07 00:24:53.6750
# ...             ...                       ...                       ...
# 62178           985  2019-10-13 23:53:53.2520  2019-10-14 00:10:18.8000
# 62181           458  2019-10-13 23:54:51.1120  2019-10-14 00:02:29.6070
# 62182           306  2019-10-13 23:56:00.1740  2019-10-14 00:01:07.0980
# 62185           459  2019-10-13 23:57:11.2610  2019-10-14 00:04:50.4560
# 62188           384  2019-10-13 23:58:30.8800  2019-10-14 00:04:55.5750
#
#        start station id                                start station name  \
# 9                    80           MIT Stata Center at Vassar St / Main St
# 15                   68             Central Square at Mass Ave / Essex St
# 19                   80           MIT Stata Center at Vassar St / Main St
# 20                   67                      MIT at Mass Ave / Amherst St
# 21                   67                      MIT at Mass Ave / Amherst St
# ...                 ...                                               ...
# 62178                91  One Kendall Square at Hampshire St / Portland St
# 62181                67                      MIT at Mass Ave / Amherst St
# 62182               178                   MIT Pacific St at Purrington St
# 62185                80           MIT Stata Center at Vassar St / Main St
# 62188               177                                   University Park
#
#        start station latitude  start station longitude  end station id  \
# 9                   42.362131               -71.091156             361
# 15                  42.365070               -71.103100              67
# 19                  42.362131               -71.091156             189
# 20                  42.358100               -71.093198              96
# 21                  42.358100               -71.093198              96
# ...                       ...                      ...             ...
# 62178               42.366277               -71.091690              17
# 62181               42.358100               -71.093198             184
# 62182               42.359573               -71.101295             107
# 62185               42.362131               -71.091156             184
# 62188               42.362648               -71.100061             105
#
#                                         end station name  \
# 9                       Deerfield St at Commonwealth Ave
# 15                          MIT at Mass Ave / Amherst St
# 19                                             Kendall T
# 20     Cambridge Main Library at Broadway / Trowbridg...
# 21     Cambridge Main Library at Broadway / Trowbridg...
# ...                                                  ...
# 62178              Soldiers Field Park - 111 Western Ave
# 62181     Sidney Research Campus/ Erie Street at Waverly
# 62182                                 Ames St at Main St
# 62185     Sidney Research Campus/ Erie Street at Waverly
# 62188  Lower Cambridgeport at Magazine St / Riverside Rd
#
#        end station latitude  ...  gender  start_building  start_lon  \
# 9                 42.349244  ...       1            4347 -71.090572
# 15                42.358100  ...       1          161771 -71.104613
# 19                42.362428  ...       0          125217 -71.089026
# 20                42.373379  ...       1            4323 -71.094771
# 21                42.373379  ...       1          257166 -71.092071
# ...                     ...  ...     ...             ...        ...
# 62178             42.364263  ...       1          260509 -71.092602
# 62181             42.357753  ...       2          257908 -71.091543
# 62182             42.362500  ...       2           85678 -71.101442
# 62185             42.357753  ...       1          201822 -71.089857
# 62188             42.357219  ...       1          225354 -71.102718
#
#        start_lat  target_building  target_lon  target_lat  start_time  \
# 9      42.361620             1320  -71.098889   42.349996       178.0
# 15     42.363118           245937  -71.093978   42.358376       445.0
# 19     42.364289           203475  -71.085133   42.364351       679.0
# 20     42.359049            63401  -71.108094   42.374189       697.0
# 21     42.359761             6748  -71.112617   42.371169       707.0
# ...          ...              ...         ...         ...         ...
# 62178  42.365204           219120  -71.118634   42.361798    604433.0
# 62181  42.360223            85602  -71.105831   42.359954    604491.0
# 62182  42.358791           153926  -71.088769   42.364947    604560.0
# 62185  42.360705           119326  -71.102440   42.357701    604631.0
# 62188  42.363217            32375  -71.111086   42.356037    604710.0
#
#        target_time  withinC
# 9            775.0     True
# 15           686.0     True
# 19          4896.0     True
# 20          1496.0     True
# 21          1493.0     True
# ...            ...      ...
# 62178     605418.0     True
# 62181     604949.0     True
# 62182     604867.0     True
# 62185     605090.0     True
# 62188     605095.0     True
#
# [11329 rows x 24 columns]

# %%
# add new column to df
demand_start_within['withinCend'] = ""

#Determine if it is inside or not
endwithinClist = []
for lon,lat in zip(demand_start_within['target_lon'],demand_start_within['target_lat']):
    pt = Point(lon, lat)
    endwithinC = pt.within(poly)
    #print( withinQ )
    endwithinClist.append(endwithinC)

# update values in the that column, values: True/False
demand_start_within['withinCend'] = endwithinClist
# Out:
# /Users/naroacorettisanchez/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/naroacorettisanchez/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
# select points with start within Cambridge, assign to `demand_start_within` dataframe
demand_halfcambridge= demand_start_within[demand_start_within.withinCend==True]
demand_halfcambridge
# Out:
#        tripduration                 starttime                  stoptime  \
# 15              240  2019-10-07 00:07:25.9850  2019-10-07 00:11:26.2400
# 30              230  2019-10-07 00:18:09.0240  2019-10-07 00:21:59.9900
# 49              382  2019-10-07 00:41:35.8970  2019-10-07 00:47:58.5430
# 58              222  2019-10-07 00:54:29.8710  2019-10-07 00:58:12.7260
# 64              443  2019-10-07 01:02:22.9890  2019-10-07 01:09:46.6800
# ...             ...                       ...                       ...
# 62177           255  2019-10-13 23:52:34.8600  2019-10-13 23:56:50.6850
# 62181           458  2019-10-13 23:54:51.1120  2019-10-14 00:02:29.6070
# 62182           306  2019-10-13 23:56:00.1740  2019-10-14 00:01:07.0980
# 62185           459  2019-10-13 23:57:11.2610  2019-10-14 00:04:50.4560
# 62188           384  2019-10-13 23:58:30.8800  2019-10-14 00:04:55.5750
#
#        start station id                                 start station name  \
# 15                   68              Central Square at Mass Ave / Essex St
# 30                   72      One Broadway / Kendall Sq at Main St / 3rd St
# 49                   67                       MIT at Mass Ave / Amherst St
# 58                   75  Lafayette Square at Mass Ave / Main St / Colum...
# 64                   67                       MIT at Mass Ave / Amherst St
# ...                 ...                                                ...
# 62177                67                       MIT at Mass Ave / Amherst St
# 62181                67                       MIT at Mass Ave / Amherst St
# 62182               178                    MIT Pacific St at Purrington St
# 62185                80            MIT Stata Center at Vassar St / Main St
# 62188               177                                    University Park
#
#        start station latitude  start station longitude  end station id  \
# 15                  42.365070               -71.103100              67
# 30                  42.362242               -71.083111              91
# 49                  42.358100               -71.093198             318
# 58                  42.363465               -71.100573              67
# 64                  42.358100               -71.093198             335
# ...                       ...                      ...             ...
# 62177               42.358100               -71.093198             178
# 62181               42.358100               -71.093198             184
# 62182               42.359573               -71.101295             107
# 62185               42.362131               -71.091156             184
# 62188               42.362648               -71.100061             105
#
#                                         end station name  \
# 15                          MIT at Mass Ave / Amherst St
# 30      One Kendall Square at Hampshire St / Portland St
# 49                                   Ames St at Broadway
# 58                          MIT at Mass Ave / Amherst St
# 64               Harvard St at Greene-Rose Heritage Park
# ...                                                  ...
# 62177                    MIT Pacific St at Purrington St
# 62181     Sidney Research Campus/ Erie Street at Waverly
# 62182                                 Ames St at Main St
# 62185     Sidney Research Campus/ Erie Street at Waverly
# 62188  Lower Cambridgeport at Magazine St / Riverside Rd
#
#        end station latitude  ...  start_building  start_lon  start_lat  \
# 15                42.358100  ...          161771 -71.104613  42.363118
# 30                42.366277  ...           49516 -71.084856  42.361174
# 49                42.363693  ...          124918 -71.093823  42.357250
# 58                42.358100  ...           28860 -71.097814  42.364313
# 64                42.365994  ...            4325 -71.093427  42.357645
# ...                     ...  ...             ...        ...        ...
# 62177             42.359573  ...           45423 -71.093517  42.358256
# 62181             42.357753  ...          257908 -71.091543  42.360223
# 62182             42.362500  ...           85678 -71.101442  42.358791
# 62185             42.357753  ...          201822 -71.089857  42.360705
# 62188             42.357219  ...          225354 -71.102718  42.363217
#
#        target_building  target_lon  target_lat  start_time  target_time  \
# 15              245937  -71.093978   42.358376       445.0        686.0
# 30              127624  -71.093730   42.366281      1089.0       1319.0
# 49              202175  -71.088652   42.363598      2495.0       2878.0
# 58              201810  -71.090183   42.358787      3269.0       3492.0
# 64              101756  -71.095308   42.366313      3742.0       4186.0
# ...                ...         ...         ...         ...          ...
# 62177           165701  -71.101976   42.361763    604354.0     604610.0
# 62181            85602  -71.105831   42.359954    604491.0     604949.0
# 62182           153926  -71.088769   42.364947    604560.0     604867.0
# 62185           119326  -71.102440   42.357701    604631.0     605090.0
# 62188            32375  -71.111086   42.356037    604710.0     605095.0
#
#        withinC  withinCend
# 15        True        True
# 30        True        True
# 49        True        True
# 58        True        True
# 64        True        True
# ...        ...         ...
# 62177     True        True
# 62181     True        True
# 62182     True        True
# 62185     True        True
# 62188     True        True
#
# [5255 rows x 25 columns]

# %%
# DATE FILTER
start_date = "2019-10-12 00:00:00"
end_date = "2019-10-13 00:00:00"
demand_cambridge = demand_halfcambridge[demand_halfcambridge["starttime"].between(start_date, end_date)]

# %%
demand_halfcambridge
# Out:
#        tripduration                 starttime                  stoptime  \
# 15              240  2019-10-07 00:07:25.9850  2019-10-07 00:11:26.2400
# 30              230  2019-10-07 00:18:09.0240  2019-10-07 00:21:59.9900
# 49              382  2019-10-07 00:41:35.8970  2019-10-07 00:47:58.5430
# 58              222  2019-10-07 00:54:29.8710  2019-10-07 00:58:12.7260
# 64              443  2019-10-07 01:02:22.9890  2019-10-07 01:09:46.6800
# ...             ...                       ...                       ...
# 62177           255  2019-10-13 23:52:34.8600  2019-10-13 23:56:50.6850
# 62181           458  2019-10-13 23:54:51.1120  2019-10-14 00:02:29.6070
# 62182           306  2019-10-13 23:56:00.1740  2019-10-14 00:01:07.0980
# 62185           459  2019-10-13 23:57:11.2610  2019-10-14 00:04:50.4560
# 62188           384  2019-10-13 23:58:30.8800  2019-10-14 00:04:55.5750
#
#        start station id                                 start station name  \
# 15                   68              Central Square at Mass Ave / Essex St
# 30                   72      One Broadway / Kendall Sq at Main St / 3rd St
# 49                   67                       MIT at Mass Ave / Amherst St
# 58                   75  Lafayette Square at Mass Ave / Main St / Colum...
# 64                   67                       MIT at Mass Ave / Amherst St
# ...                 ...                                                ...
# 62177                67                       MIT at Mass Ave / Amherst St
# 62181                67                       MIT at Mass Ave / Amherst St
# 62182               178                    MIT Pacific St at Purrington St
# 62185                80            MIT Stata Center at Vassar St / Main St
# 62188               177                                    University Park
#
#        start station latitude  start station longitude  end station id  \
# 15                  42.365070               -71.103100              67
# 30                  42.362242               -71.083111              91
# 49                  42.358100               -71.093198             318
# 58                  42.363465               -71.100573              67
# 64                  42.358100               -71.093198             335
# ...                       ...                      ...             ...
# 62177               42.358100               -71.093198             178
# 62181               42.358100               -71.093198             184
# 62182               42.359573               -71.101295             107
# 62185               42.362131               -71.091156             184
# 62188               42.362648               -71.100061             105
#
#                                         end station name  \
# 15                          MIT at Mass Ave / Amherst St
# 30      One Kendall Square at Hampshire St / Portland St
# 49                                   Ames St at Broadway
# 58                          MIT at Mass Ave / Amherst St
# 64               Harvard St at Greene-Rose Heritage Park
# ...                                                  ...
# 62177                    MIT Pacific St at Purrington St
# 62181     Sidney Research Campus/ Erie Street at Waverly
# 62182                                 Ames St at Main St
# 62185     Sidney Research Campus/ Erie Street at Waverly
# 62188  Lower Cambridgeport at Magazine St / Riverside Rd
#
#        end station latitude  ...  start_building  start_lon  start_lat  \
# 15                42.358100  ...          161771 -71.104613  42.363118
# 30                42.366277  ...           49516 -71.084856  42.361174
# 49                42.363693  ...          124918 -71.093823  42.357250
# 58                42.358100  ...           28860 -71.097814  42.364313
# 64                42.365994  ...            4325 -71.093427  42.357645
# ...                     ...  ...             ...        ...        ...
# 62177             42.359573  ...           45423 -71.093517  42.358256
# 62181             42.357753  ...          257908 -71.091543  42.360223
# 62182             42.362500  ...           85678 -71.101442  42.358791
# 62185             42.357753  ...          201822 -71.089857  42.360705
# 62188             42.357219  ...          225354 -71.102718  42.363217
#
#        target_building  target_lon  target_lat  start_time  target_time  \
# 15              245937  -71.093978   42.358376       445.0        686.0
# 30              127624  -71.093730   42.366281      1089.0       1319.0
# 49              202175  -71.088652   42.363598      2495.0       2878.0
# 58              201810  -71.090183   42.358787      3269.0       3492.0
# 64              101756  -71.095308   42.366313      3742.0       4186.0
# ...                ...         ...         ...         ...          ...
# 62177           165701  -71.101976   42.361763    604354.0     604610.0
# 62181            85602  -71.105831   42.359954    604491.0     604949.0
# 62182           153926  -71.088769   42.364947    604560.0     604867.0
# 62185           119326  -71.102440   42.357701    604631.0     605090.0
# 62188            32375  -71.111086   42.356037    604710.0     605095.0
#
#        withinC  withinCend
# 15        True        True
# 30        True        True
# 49        True        True
# 58        True        True
# 64        True        True
# ...        ...         ...
# 62177     True        True
# 62181     True        True
# 62182     True        True
# 62185     True        True
# 62188     True        True
#
# [5255 rows x 25 columns]

# %%
demand_halfcambridge.to_csv("./data/demand_halfcambridge.csv", index=False)

# %% [markdown]
# ****************************************************************************************************************************************************

# %%
place = [
    {"city": "Cambridge", "state": "Massachusetts"}
]

# %%
G = ox.graph_from_place(place, network_type="drive")

# %%
fig, ax = ox.plot_graph(G, node_size=0, edge_color="w", edge_linewidth=0.2)

# %%
gdf = ox.geocode_to_gdf(place)
gdf_proj = ox.project_gdf(gdf)
ax = gdf_proj.plot(fc="gray", ec="w")
_ = ax.axis("off")

# %%
gdf.loc[0,'geometry']

# %%
gdf.to_file('cambridge-boundary')
# Out:
# /Users/naroacorettisanchez/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   """Entry point for launching an IPython kernel.

# %%
from shapely.geometry import Point  #Polygon
import pandas as pd

# %%
demand_raw = pd.read_csv("./input_data/user_trips_0.csv")
demand_raw
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               176  2019-10-07 00:00:01.5740  2019-10-07 00:02:57.8570
# 1               193  2019-10-07 00:00:43.0660  2019-10-07 00:03:56.4360
# 2               159  2019-10-07 00:01:29.1760  2019-10-07 00:04:08.3340
# 3               540  2019-10-07 00:01:30.6650  2019-10-07 00:10:31.6250
# 4               531  2019-10-07 00:01:30.8390  2019-10-07 00:10:22.4090
# ...             ...                       ...                       ...
# 62187          1074  2019-10-13 23:58:29.5130  2019-10-14 00:16:24.0190
# 62188           384  2019-10-13 23:58:30.8800  2019-10-14 00:04:55.5750
# 62189           502  2019-10-13 23:58:37.6720  2019-10-14 00:07:00.3150
# 62190           311  2019-10-13 23:59:29.5320  2019-10-14 00:04:41.2130
# 62191           835  2019-10-13 23:59:55.1170  2019-10-14 00:13:51.0050
#
#        start station id                                 start station name  \
# 0                   108  Harvard University / SEAS Cruft-Pierce Halls a...
# 1                    10                      B.U. Central - 725 Comm. Ave.
# 2                     9                    Commonwealth Ave at Agganis Way
# 3                     3  Colleges of the Fenway - Fenway at Avenue Loui...
# 4                     3  Colleges of the Fenway - Fenway at Avenue Loui...
# ...                 ...                                                ...
# 62187                 3  Colleges of the Fenway - Fenway at Avenue Loui...
# 62188               177                                    University Park
# 62189                52                          Newbury St at Hereford St
# 62190                 9                    Commonwealth Ave at Agganis Way
# 62191                 4                        Tremont St at E Berkeley St
#
#        start station latitude  start station longitude  end station id  \
# 0                   42.377945               -71.116865              79
# 1                   42.350406               -71.108279              19
# 2                   42.351692               -71.119035              41
# 3                   42.340115               -71.100619              12
# 4                   42.340115               -71.100619              12
# ...                       ...                      ...             ...
# 62187               42.340115               -71.100619              37
# 62188               42.362648               -71.100061             105
# 62189               42.348717               -71.085954             122
# 62190               42.351692               -71.119035              66
# 62191               42.345392               -71.069616             342
#
#                                         end station name  \
# 0                     Beacon St at Washington / Kirkland
# 1                                  Park Dr at Buswell St
# 2      Packard's Corner - Commonwealth Ave at Brighto...
# 3      Ruggles T Stop - Columbus Ave at Melnea Cass Blvd
# 4      Ruggles T Stop - Columbus Ave at Melnea Cass Blvd
# ...                                                  ...
# 62187                          New Balance - 20 Guest St
# 62188  Lower Cambridgeport at Magazine St / Riverside Rd
# 62189                    Burlington Ave at Brookline Ave
# 62190  Allston Green District - Griggs St at Commonwe...
# 62191                           Boylston St at Jersey St
#
#        end station latitude  ...  birth year  gender start_building  \
# 0                 42.378420  ...        1983       1          87796
# 1                 42.347241  ...        1999       2            183
# 2                 42.352261  ...        1999       1         180997
# 3                 42.336244  ...        1969       0            201
# 4                 42.336244  ...        1969       0         202657
# ...                     ...  ...         ...     ...            ...
# 62187             42.357329  ...        1989       1         259759
# 62188             42.357219  ...        1996       1         225354
# 62189             42.345733  ...        1985       1         257268
# 62190             42.349225  ...        1997       1         224577
# 62191             42.344651  ...        1987       2         251112
#
#        start_lon  start_lat  target_building  target_lon  target_lat  \
# 0     -71.113726  42.377668            17007  -71.105017   42.378432
# 1     -71.111674  42.350137             1384  -71.104996   42.347869
# 2     -71.121202  42.350776           175311  -71.122811   42.350820
# 3     -71.103059  42.338554           259390  -71.084691   42.336693
# 4     -71.099701  42.338420           248527  -71.086064   42.336684
# ...          ...        ...              ...         ...         ...
# 62187 -71.103671  42.340555            62890  -71.146244   42.355139
# 62188 -71.102718  42.363217            32375  -71.111086   42.356037
# 62189 -71.085335  42.346976           162379  -71.102816   42.346085
# 62190 -71.118932  42.350876           185148  -71.135520   42.350418
# 62191 -71.068436  42.344313            23940  -71.098384   42.344760
#
#        start_time  target_time
# 0             1.0        177.0
# 1            43.0        236.0
# 2            89.0        248.0
# 3            90.0        631.0
# 4            90.0        622.0
# ...           ...          ...
# 62187    604709.0     605784.0
# 62188    604710.0     605095.0
# 62189    604717.0     605220.0
# 62190    604769.0     605081.0
# 62191    604795.0     605631.0
#
# [62192 rows x 23 columns]

# %%
# add new column to df
demand_raw['withinC'] = ""

#Determine if it is inside or not
startwithinClist = []
for lon,lat in zip(demand_raw['start_lon'],demand_raw['start_lat']):
    pt = Point(lon, lat)
    startwithinC = pt.within(cambridge_b)
    #print( withinQ )
    startwithinClist.append(startwithinC)

# update values in the that column, values: True/False
demand_raw['withinC'] = startwithinClist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4c999112c062> in <module>
#       6 for lon,lat in zip(demand_raw['start_lon'],demand_raw['start_lat']):
#       7     pt = Point(lon, lat)
# ----> 8     startwithinC = pt.within(cambridge_b)
#       9     #print( withinQ )
#      10     startwithinClist.append(startwithinC)
#
# NameError: name 'cambridge_b' is not defined

# %%
# select points with start within Cambridge, assign to `demand_start_within` dataframe
demand_start_within = demand_raw[demand_raw.withinC==True]
demand_start_within
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               176  2019-10-07 00:00:01.5740  2019-10-07 00:02:57.8570
# 9               597  2019-10-07 00:02:58.3520  2019-10-07 00:12:55.7150
# 13              552  2019-10-07 00:06:52.1970  2019-10-07 00:16:05.0870
# 15              240  2019-10-07 00:07:25.9850  2019-10-07 00:11:26.2400
# 16              828  2019-10-07 00:09:13.4160  2019-10-07 00:23:01.9710
# ...             ...                       ...                       ...
# 62178           985  2019-10-13 23:53:53.2520  2019-10-14 00:10:18.8000
# 62181           458  2019-10-13 23:54:51.1120  2019-10-14 00:02:29.6070
# 62182           306  2019-10-13 23:56:00.1740  2019-10-14 00:01:07.0980
# 62185           459  2019-10-13 23:57:11.2610  2019-10-14 00:04:50.4560
# 62188           384  2019-10-13 23:58:30.8800  2019-10-14 00:04:55.5750
#
#        start station id                                 start station name  \
# 0                   108  Harvard University / SEAS Cruft-Pierce Halls a...
# 9                    80            MIT Stata Center at Vassar St / Main St
# 13                  221              Verizon Innovation Hub 10 Ware Street
# 15                   68              Central Square at Mass Ave / Essex St
# 16                  381                    Inman Square at Springfield St.
# ...                 ...                                                ...
# 62178                91   One Kendall Square at Hampshire St / Portland St
# 62181                67                       MIT at Mass Ave / Amherst St
# 62182               178                    MIT Pacific St at Purrington St
# 62185                80            MIT Stata Center at Vassar St / Main St
# 62188               177                                    University Park
#
#        start station latitude  start station longitude  end station id  \
# 0                   42.377945               -71.116865              79
# 9                   42.362131               -71.091156             361
# 13                  42.372509               -71.113054              67
# 15                  42.365070               -71.103100              67
# 16                  42.374384               -71.100157             115
# ...                       ...                      ...             ...
# 62178               42.366277               -71.091690              17
# 62181               42.358100               -71.093198             184
# 62182               42.359573               -71.101295             107
# 62185               42.362131               -71.091156             184
# 62188               42.362648               -71.100061             105
#
#                                         end station name  \
# 0                     Beacon St at Washington / Kirkland
# 9                       Deerfield St at Commonwealth Ave
# 13                          MIT at Mass Ave / Amherst St
# 15                          MIT at Mass Ave / Amherst St
# 16                                 Porter Square Station
# ...                                                  ...
# 62178              Soldiers Field Park - 111 Western Ave
# 62181     Sidney Research Campus/ Erie Street at Waverly
# 62182                                 Ames St at Main St
# 62185     Sidney Research Campus/ Erie Street at Waverly
# 62188  Lower Cambridgeport at Magazine St / Riverside Rd
#
#        end station latitude  ...  start_building  start_lon  start_lat  \
# 0                 42.378420  ...           87796 -71.113726  42.377668
# 9                 42.349244  ...            4347 -71.090572  42.361620
# 13                42.358100  ...          225842 -71.115025  42.370528
# 15                42.358100  ...          161771 -71.104613  42.363118
# 16                42.387995  ...          117488 -71.100734  42.371848
# ...                     ...  ...             ...        ...        ...
# 62178             42.364263  ...          260509 -71.092602  42.365204
# 62181             42.357753  ...          257908 -71.091543  42.360223
# 62182             42.362500  ...           85678 -71.101442  42.358791
# 62185             42.357753  ...          201822 -71.089857  42.360705
# 62188             42.357219  ...          225354 -71.102718  42.363217
#
#        target_building  target_lon  target_lat  start_time  target_time  \
# 0                17007  -71.105017   42.378432         1.0        177.0
# 9                 1320  -71.098889   42.349996       178.0        775.0
# 13              201826  -71.094033   42.360384       412.0        965.0
# 15              245937  -71.093978   42.358376       445.0        686.0
# 16               59022  -71.117094   42.389462       553.0       1381.0
# ...                ...         ...         ...         ...          ...
# 62178           219120  -71.118634   42.361798    604433.0     605418.0
# 62181            85602  -71.105831   42.359954    604491.0     604949.0
# 62182           153926  -71.088769   42.364947    604560.0     604867.0
# 62185           119326  -71.102440   42.357701    604631.0     605090.0
# 62188            32375  -71.111086   42.356037    604710.0     605095.0
#
#        startwithinC  withinC
# 0                       True
# 9                       True
# 13                      True
# 15                      True
# 16                      True
# ...             ...      ...
# 62178                   True
# 62181                   True
# 62182                   True
# 62185                   True
# 62188                   True
#
# [22006 rows x 25 columns]

# %%
# add new column to df
demand_start_within['withinCend'] = ""

#Determine if it is inside or not
endwithinClist = []
for lon,lat in zip(demand_start_within['target_lon'],demand_start_within['target_lat']):
    pt = Point(lon, lat)
    endwithinC = pt.within(cambridge_b)
    #print( withinQ )
    endwithinClist.append(endwithinC)

# update values in the that column, values: True/False
demand_start_within['withinCend'] = endwithinClist
# Out:
# /Users/naroacorettisanchez/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/naroacorettisanchez/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
# select points with start within Cambridge, assign to `demand_start_within` dataframe
demand_cambridge= demand_start_within[demand_start_within.withinCend==True]
demand_cambridge
# Out:
#        tripduration                 starttime                  stoptime  \
# 13              552  2019-10-07 00:06:52.1970  2019-10-07 00:16:05.0870
# 15              240  2019-10-07 00:07:25.9850  2019-10-07 00:11:26.2400
# 19             4217  2019-10-07 00:11:19.1750  2019-10-07 01:21:36.4020
# 20              799  2019-10-07 00:11:37.2620  2019-10-07 00:24:56.6760
# 21              785  2019-10-07 00:11:47.9830  2019-10-07 00:24:53.6750
# ...             ...                       ...                       ...
# 62177           255  2019-10-13 23:52:34.8600  2019-10-13 23:56:50.6850
# 62181           458  2019-10-13 23:54:51.1120  2019-10-14 00:02:29.6070
# 62182           306  2019-10-13 23:56:00.1740  2019-10-14 00:01:07.0980
# 62185           459  2019-10-13 23:57:11.2610  2019-10-14 00:04:50.4560
# 62188           384  2019-10-13 23:58:30.8800  2019-10-14 00:04:55.5750
#
#        start station id                       start station name  \
# 13                  221    Verizon Innovation Hub 10 Ware Street
# 15                   68    Central Square at Mass Ave / Essex St
# 19                   80  MIT Stata Center at Vassar St / Main St
# 20                   67             MIT at Mass Ave / Amherst St
# 21                   67             MIT at Mass Ave / Amherst St
# ...                 ...                                      ...
# 62177                67             MIT at Mass Ave / Amherst St
# 62181                67             MIT at Mass Ave / Amherst St
# 62182               178          MIT Pacific St at Purrington St
# 62185                80  MIT Stata Center at Vassar St / Main St
# 62188               177                          University Park
#
#        start station latitude  start station longitude  end station id  \
# 13                  42.372509               -71.113054              67
# 15                  42.365070               -71.103100              67
# 19                  42.362131               -71.091156             189
# 20                  42.358100               -71.093198              96
# 21                  42.358100               -71.093198              96
# ...                       ...                      ...             ...
# 62177               42.358100               -71.093198             178
# 62181               42.358100               -71.093198             184
# 62182               42.359573               -71.101295             107
# 62185               42.362131               -71.091156             184
# 62188               42.362648               -71.100061             105
#
#                                         end station name  \
# 13                          MIT at Mass Ave / Amherst St
# 15                          MIT at Mass Ave / Amherst St
# 19                                             Kendall T
# 20     Cambridge Main Library at Broadway / Trowbridg...
# 21     Cambridge Main Library at Broadway / Trowbridg...
# ...                                                  ...
# 62177                    MIT Pacific St at Purrington St
# 62181     Sidney Research Campus/ Erie Street at Waverly
# 62182                                 Ames St at Main St
# 62185     Sidney Research Campus/ Erie Street at Waverly
# 62188  Lower Cambridgeport at Magazine St / Riverside Rd
#
#        end station latitude  ...  start_lon  start_lat target_building  \
# 13                42.358100  ... -71.115025  42.370528          201826
# 15                42.358100  ... -71.104613  42.363118          245937
# 19                42.362428  ... -71.089026  42.364289          203475
# 20                42.373379  ... -71.094771  42.359049           63401
# 21                42.373379  ... -71.092071  42.359761            6748
# ...                     ...  ...        ...        ...             ...
# 62177             42.359573  ... -71.093517  42.358256          165701
# 62181             42.357753  ... -71.091543  42.360223           85602
# 62182             42.362500  ... -71.101442  42.358791          153926
# 62185             42.357753  ... -71.089857  42.360705          119326
# 62188             42.357219  ... -71.102718  42.363217           32375
#
#        target_lon  target_lat  start_time  target_time  startwithinC  withinC  \
# 13     -71.094033   42.360384       412.0        965.0                   True
# 15     -71.093978   42.358376       445.0        686.0                   True
# 19     -71.085133   42.364351       679.0       4896.0                   True
# 20     -71.108094   42.374189       697.0       1496.0                   True
# 21     -71.112617   42.371169       707.0       1493.0                   True
# ...           ...         ...         ...          ...           ...      ...
# 62177  -71.101976   42.361763    604354.0     604610.0                   True
# 62181  -71.105831   42.359954    604491.0     604949.0                   True
# 62182  -71.088769   42.364947    604560.0     604867.0                   True
# 62185  -71.102440   42.357701    604631.0     605090.0                   True
# 62188  -71.111086   42.356037    604710.0     605095.0                   True
#
#        withinCend
# 13           True
# 15           True
# 19           True
# 20           True
# 21           True
# ...           ...
# 62177        True
# 62181        True
# 62182        True
# 62185        True
# 62188        True
#
# [14217 rows x 26 columns]

# %%
# DATE FILTER
start_date = "2019-10-12 00:00:00"
end_date = "2019-10-13 00:00:00"
demand_cambridge = demand_cambridge[demand_cambridge["starttime"].between(start_date, end_date)]

# %%
demand_cambridge
# Out:
#        tripduration                 starttime                  stoptime  \
# 46344           780  2019-10-12 00:04:16.2290  2019-10-12 00:17:17.1730
# 46347           607  2019-10-12 00:06:41.3590  2019-10-12 00:16:48.8690
# 46350           399  2019-10-12 00:13:43.0320  2019-10-12 00:20:22.2090
# 46356          1286  2019-10-12 00:22:05.2650  2019-10-12 00:43:31.6530
# 46358           266  2019-10-12 00:27:08.2650  2019-10-12 00:31:35.0010
# ...             ...                       ...                       ...
# 52821           243  2019-10-12 23:51:09.0340  2019-10-12 23:55:12.2260
# 52822           107  2019-10-12 23:51:20.6290  2019-10-12 23:53:08.3420
# 52828           413  2019-10-12 23:55:19.3900  2019-10-13 00:02:12.9360
# 52834           526  2019-10-12 23:58:04.7220  2019-10-13 00:06:51.4320
# 52841           423  2019-10-12 23:59:30.4850  2019-10-13 00:06:33.5560
#
#        start station id                                 start station name  \
# 46344               110  Harvard University Gund Hall at Quincy St / Ki...
# 46347                74                Harvard Square at Mass Ave/ Dunster
# 46350                68              Central Square at Mass Ave / Essex St
# 46356               104  Harvard University Radcliffe Quadrangle at She...
# 46358                73            Harvard Square at Brattle St / Eliot St
# ...                 ...                                                ...
# 52821               221              Verizon Innovation Hub 10 Ware Street
# 52822               178                    MIT Pacific St at Purrington St
# 52828                97  Harvard University River Houses at DeWolfe St ...
# 52834                74                Harvard Square at Mass Ave/ Dunster
# 52841               108  Harvard University / SEAS Cruft-Pierce Halls a...
#
#        start station latitude  start station longitude  end station id  \
# 46344               42.376369               -71.114025             195
# 46347               42.373268               -71.118579             378
# 46350               42.365070               -71.103100             225
# 46356               42.380287               -71.125107             381
# 46358               42.373231               -71.120886              97
# ...                       ...                      ...             ...
# 52821               42.372509               -71.113054             108
# 52822               42.359573               -71.101295             184
# 52828               42.369190               -71.117141             108
# 52834               42.373268               -71.118579             139
# 52841               42.377945               -71.116865              87
#
#                                         end station name  \
# 46344                               Child St at North St
# 46347                                      191 Beacon St
# 46350  Cambridge Dept. of Public Works -147 Hampshire...
# 46356                    Inman Square at Springfield St.
# 46358  Harvard University River Houses at DeWolfe St ...
# ...                                                  ...
# 52821  Harvard University / SEAS Cruft-Pierce Halls a...
# 52822     Sidney Research Campus/ Erie Street at Waverly
# 52828  Harvard University / SEAS Cruft-Pierce Halls a...
# 52834                                          Dana Park
# 52841  Harvard University Housing - 115 Putnam Ave at...
#
#        end station latitude  ...  start_lon  start_lat target_building  \
# 46344             42.371505  ... -71.114297  42.376962          101602
# 46347             42.380323  ... -71.119092  42.373454           15320
# 46350             42.371197  ... -71.103942  42.362618          102897
# 46356             42.374384  ... -71.122707  42.381831           87930
# 46358             42.369190  ... -71.121979  42.375460           96622
# ...                     ...  ...        ...        ...             ...
# 52821             42.377945  ... -71.113790  42.371106           59818
# 52822             42.357753  ... -71.100506  42.358580          161417
# 52828             42.377945  ... -71.114190  42.370217            6462
# 52834             42.361780  ... -71.119992  42.373170          257275
# 52841             42.366621  ... -71.114291  42.378626          184668
#
#        target_lon  target_lat  start_time  target_time  startwithinC  withinC  \
# 46344  -71.069626   42.370257    432256.0     433037.0                   True
# 46347  -71.111959   42.380158    432401.0     433008.0                   True
# 46350  -71.099089   42.371193    432823.0     433222.0                   True
# 46356  -71.103087   42.373230    433325.0     434611.0                   True
# 46358  -71.116454   42.370049    433628.0     433895.0                   True
# ...           ...         ...         ...          ...           ...      ...
# 52821  -71.119258   42.376697    517869.0     518112.0                   True
# 52822  -71.104468   42.359425    517880.0     517988.0                   True
# 52828  -71.114799   42.378572    518119.0     518532.0                   True
# 52834  -71.110613   42.363111    518284.0     518811.0                   True
# 52841  -71.110794   42.367402    518370.0     518793.0                   True
#
#        withinCend
# 46344        True
# 46347        True
# 46350        True
# 46356        True
# 46358        True
# ...           ...
# 52821        True
# 52822        True
# 52828        True
# 52834        True
# 52841        True
#
# [1457 rows x 26 columns]

# %%
demand_cambridge.to_csv("./data/demand_cambridge_oct12.csv", index=False)
